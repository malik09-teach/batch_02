# %%
print(type(list))
# Out:
# <class 'type'>

# %%
name="abbas"
name
type(name)
# Out:
# str

# %%
names_list=["abbas","huzaifa ","alishba ","iqra"]
print(type(names_list))
class4th_sec_c=[89,34,32,23,11]

class4th_sec_c
# Out:
# <class 'list'>
# [89, 34, 32, 23, 11]

# %%
print(names_list)
# Out:
# ['abbas', 'huzaifa ', 'alishba ', 'iqra']

# %%
single_e=["ababs"]
single_e
# Out:
# ['ababs']

# %%
list_subj=[]

for sub in range(0,3):
    subject=input("enter subj")
    #list_subj[sub]=subject
    list_subj.append(subject)

# %%
list_subj
# Out:
# ['math', 'pt', 'python', 'ss', 'ss', 'ss', 'huzaifa ', '213123', '3.0']

# %%
even_num=[i for i in range(0,11,2)]

# %%
even_num
# Out:
# [0, 2, 4, 6, 8, 10]

# %%
hetro_gen=["abbas","1245547567856","xyz",3894720394,3.5]

# %%
print(hetro_gen)
# Out:
# ['abbas', '1245547567856', 'xyz', 3894720394, 3.5]

# %%
mix_list=[]

for sub in range(0,3):
    ent=input("enter ent")
    mix_list.append(ent)

# %%
mix_list
# Out:
# ['huzaifa', '12134', '3.0']
