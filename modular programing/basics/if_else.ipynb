# %% [markdown]
# # SINGLE IF

# %%
input("")


if budget != "300b$":
    print ("poor country")

# %% [markdown]
# # IF ELSE

# %% [markdown]
# # IF - ELIF -ELSE

# %% [markdown]
# # MULTI IF AND EL-IF
