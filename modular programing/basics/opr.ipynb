# %%
print(2**2)
# Out:
# 4

# %%
base=int(input("enter base"))
power=int(input("enter power"))

total=base**power
print ("total number:",total)
# Out:
# total number: 243

# %%
#ASIGNING OPREATOR 

NUM1=5
NUM2=5.5
NAME="ABBAS"
NAME2='ABBAS KHAN' 

print(type(NAME))
# Out:
# <class 'str'>

# %%
# CAMPEARSION 

var=4
var2=5
print(var==5)
print(var2==5)
# Out:
# False
# True

# %%
print(var2!=5)
# Out:
# False

# %%
print(var2>=5)
# Out:
# True

# %%
## conditions AND 
var1=True 
var2=False
var3=True
var4=False


print ("t and f",var1 and var2)
print ("f and t",var2 and var3)
print ("f and f",var2 and var4)
print ("t and t",var1 and var3)
# Out:
# t and f False
# f and t False
# f and f False
# t and t True

# %%
## conditions or
var1=True 
var2=False
var3=True
var4=False


print ("t and f",var1 or var2)
print ("f and t",var2 or var3)
print ("f and f",var2 or var4)
print ("t and t",var1 or var3)
# Out:
# t and f True
# f and t True
# f and f False
# t and t True

# %%
##  not
var1=True 
var2=False


print ("t ",not(var1) )
print ("f ",not(var2))
# Out:
# t  False
# f  True

# %%
w=50
h=4.9

if (w<60 and h>5.7):
    print ("your selected")
    
else :
    
    print ("you not selected")
# Out:
# you not selected

# %%
# assignment operators 

var=50

print (var)
# Out:
# 50

# %%
var+=10

print (var)
# Out:
# 60

# %%
var-=20
print(var)
# Out:
# 40

# %%
# WALRUS OPERATOR 

name="abbas khan"

lent=len(name)

if lent>=5:
    print("not a good name ")
else :
    print("good name ")
# Out:
# not a good name

# %%
if (n:= len(name))>=5:
    print ("not good name ")
    
else :
    print ("good name ")
# Out:
# not good name

# %%
## 
l1=[1,2,3]
l2=[1,2,3]
l3=l1

# %%
print(l1==l2)
print(l1 is l2)
print(l1 is not l2)
print(l1 is l3)
print(l1 is not l3)
# Out:
# True
# False
# True
# True
# False

# %%
print (6&5)
# Out:
# 4

# %%
print (~6)
# Out:
# -7

# %%
v1=5
print(v1)
print(type(v1))



v1=5.5
print(v1)
print(type(v1))


v1="abbas"
print(v1)
print(type(v1))


v1=True
print(v1)
print(type(v1))
# Out:
# 5
# <class 'int'>
# 5.5
# <class 'float'>
# abbas
# <class 'str'>
# True
# <class 'bool'>

# %%
print("abbas")
print(5)
print (1+1)
# Out:
# abbas
# 5
# 2

# %%
print("the number is:",5)
# Out:
# the number is: 5

# %%
print(f"the lowest number is :{5} and the greatest is :{10}")
# Out:
# the lowest number is :5 and the greatest is :10

# %%
print("%d number",5)
# Out:
# %d number 5

# %%
x=input("enter any thing")

print ("input was :",x)
# Out:
# input was : True

# %%
x=int(input("enter cnic"))
print("cnic:",x)
# Out:
# cnic: 3442

# %%
x=int(input("enter cnic"))
print("cnic:",x)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 x=int(input("enter cnic"))
#       2 print("cnic:",x)
#
# ValueError: invalid literal for int() with base 10: "abbas'"

# %%
x=float(input("enter marks percentage"))
print(f"percentage:%{x}")
# Out:
# percentage:%88.9

# %%
x=str(input("where are u from? "))
print(f"i am from {x}\n")

print ("welcome ")
# Out:
# i am from peshawer
#
# welcome

# %%
#this block function    
'''this is block function 

'''

"""

this will be directly not exe

"""
# Out:
# '\n\nthis will be directly not exe\n\n'

# %%
V1=5
print(V1)
v1=5.5
print(v1)
# Out:
# 5
# 5.5

# %%
1v=9
# Out:
#   Cell In[22], line 1
#     1v=9
#     ^
# SyntaxError: invalid decimal literal

# %%
x=7.4
print(x)
print(type(x))


x1=int(x)
print(x1)
print(type(x1))
# Out:
# 7.4
# <class 'float'>
# 7
# <class 'int'>

# %%
x=input("Enter name ")

print(f"i am {x} old")
# Out:
# i am 24 old
