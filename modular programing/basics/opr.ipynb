# %%
print(2**2)
# Out:
# 4

# %%
base=int(input("enter base"))
power=int(input("enter power"))

total=base**power
print ("total number:",total)
# Out:
# total number: 243

# %%
#ASIGNING OPREATOR 

NUM1=5
NUM2=5.5
NAME="ABBAS"
NAME2='ABBAS KHAN' 

print(type(NAME))
# Out:
# <class 'str'>

# %%
# CAMPEARSION 

var=4
var2=5
print(var==5)
print(var2==5)
# Out:
# False
# True

# %%
print(var2!=5)
# Out:
# False

# %%
print(var2>=5)
# Out:
# True
