# %%
# single block 

temp=21

if temp>25:
    print("sunny today ")

# %%
if temp>25:
    print("sunny today")
else:
    print("room temperature")
# Out:
# room temperature

# %%
temp =15

if temp==25:
    print("Room temp")
    
if temp==15:
    print("mild room temp")
if temp==10:
    print("cold temp")
else:    
    print("snow ")
# Out:
# mild room temp
# snow

# %%
temp =7

if temp>=25:
    print("hot temp")
    
elif temp>=15:
    print("mild room temp")
elif temp>=10:
    print("cold temp")
else:    
    print("snow ")
# Out:
# snow

# %%
user_name=["jon","iqra","alishba","huzaifa"]
passwords=["kmix112","huzaifa123","@alishba9","iqra11#$#"]

otps=[111,121,112]

# %%
name=str(input("enter your name.."))
password=str(input("enter passcode.."))
otp=int(input("enter otp.."))


if name in user_name and password in passwords and otp in otps:
    print ("your login to the system ......")
    
else :
    print("passwords or user_name incorrect.....")
# Out:
# passwords or user_name incorrect.....

# %%
name=str(input("enter your name.."))
if name in user_name:
    print("user_name is correct and procced to password...")
    password=str(input("enter passcode.."))
    if password in passwords:
        print("you login to system")
        
    else :
        print("please put correct password ...")    
else:
    print ("user_name is wrong")
# Out:
# user_name is wrong
