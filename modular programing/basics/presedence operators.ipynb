# %%
res=(6/2)*4+6/(6+2)
print(res)
# Out:
# 12.75

# %%
add_age=int(input("add_age"))
city=input("city ")

rst=((18+add_age)>=18 and (city=="multan"))


if rst==True:
    print("eligable")
else :
    print ("not eligable")
# Out:
# not eligable
