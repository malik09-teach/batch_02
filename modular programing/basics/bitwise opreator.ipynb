# %%
input1=int(input("enter number1"))
input2=int(input("enter number 2"))


res=input1&input2



print("num2:",input1)

print("num1:",input2)


print("& operator res:",res)
# Out:
# num2: 5
# num1: 6
# & operator res: 4

# %%
input1=int(input("enter number1"))
input2=int(input("enter number 2"))


res=input1|input2



print("num2:",input1)

print("num1:",input2)


print("| operator res:",res)
# Out:
# num2: 4
# num1: 5
# | operator res: 5

# %%
input1=int(input("enter number1"))
input2=int(input("enter number 2"))


res=input1^input2



print("num2:",input1)

print("num1:",input2)


print("| operator res:",res)
# Out:
# num2: 4
# num1: 5
# | operator res: 1

# %%
input1=int(input("enter number1"))

res=~(input1)



print("num2:",input1)



print("~ operator res:",res)
# Out:
# num2: 6
# ~ operator res: -7

# %%
input1=int(input("enter number1"))
shift=int(input("enter shift:"))


res=input1>>shift



print("num2:",input1)

print("shift:",input2)


print(">> operator res:",res)
# Out:
# num2: 6
# shift: 2
# >> operator res: 1

# %%
input1=int(input("enter number1"))
shift=int(input("enter shift:"))


res=input1<<shift



print("num2:",input1)

print("shift:",input2)


print("<< operator res:",res)
# Out:
# num2: 1
# shift: 2
# << operator res: 4
