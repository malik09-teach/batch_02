# %%
amount =10000

print(amount)
# Out:
# 10000

# %%
amount+=50000


print(amount)
# Out:
# 60000

# %%
amount+= (100+400)
# amount +=(a+b)


print(amount)
# Out:
# 61500

# %%
amount-=14056

print(amount)
# Out:
# 47444

# %%
amount-= (1-50000)

# %%
print (amount)
# Out:
# 97443

# %%
print(1-50000)
# Out:
# -49999
