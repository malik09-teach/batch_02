# %%
num1=5
num2=2

# %%
result=num1+num2 
print("sum of num1 and num2",result)
# Out:
# sum of num1 and num2 7

# %%
result=num1-num2 
print("sub of num1 and num2",result)
# Out:
# sub of num1 and num2 3

# %%
result=num1*num2 
print("mul of num1 and num2",result)
# Out:
# mul of num1 and num2 10

# %%
result=num1/num2 
print("div of num1 and num2",result)
# Out:
# div of num1 and num2 2.5

# %%
result=num1**num2 
print(f"{5} power {2}={result}")
# Out:
# 5 power 2=25

# %%
result=num1%num2 
print("mod of 5 and 2=",result)
# Out:
# mod of 5 and 2= 1

# %%
result=4//2
print("celling  of 5 //2=",result)
# Out:
# celling  of 5 //2= 2.0

# %%
# getting input from user -----

num1=int(input("enter num1"))
num2=int(input("enter num2"))
 
 
print("num1 entered:",num1)

print("num1 entered:",num2)

result=num1+num2 
print("add=",result)   
result=num1-num2 
print("sub=",result)   
result=num1*num2 
print("mul=",result)   
result=num1/num2 
print("div=",result)   
result=num1**num2 
print("power=",result)   
result=num1%num2 
print("mod=",result)   
result=num1//num2 
print("celling=",result)
# Out:
# num1 entered: 13
# num1 entered: 2
# add= 15
# sub= 11
# mul= 26
# div= 6.5
# power= 169
# mod= 1
# celling= 6
