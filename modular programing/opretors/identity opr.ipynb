# %%
n1="abbas"
n2="abbas"


l1=["abbas"]
l2=["abbas"]

# %%
print(n1 is n2)


print (l1 is l2)


print(id(l1))
print(id(l2))
# Out:
# True
# False
# 2141175936704
# 2141176022848

# %%
print(id(n1))
print(id(n2))
# Out:
# 2141169640560
# 2141169640560

# %%
print (n1 is not n2)
print(l1 is not l2)
# Out:
# False
# True

# %% [markdown]
# # MEMBER SHIP OPERATOR

# %%
CINC="1245-1222-1"

# %%
print("1245" in CINC)
# Out:
# True

# %%
print("1275" not in CINC)
# Out:
# True

# %%
code="x12-111-x1x-99z"


x= str(input("enter code"))



if x in code:
    print("welcome to software")
    
else :
    print("wrong code")
# Out:
# wrong code
