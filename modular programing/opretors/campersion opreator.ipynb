# %%
x1=int(input("enter num1:"))
x2=int(input("enter num2:"))


print("entered number 1:",x1)

print("entered number 2:",x2)


r=(x1==x2)
print("==",r)

r=(x1>x2)
print(">",r)

r=(x1<x2)
print("<",r)

r=(x1>=x2)
print(">=",r)

r=(x1<=x2)
print("<=",r)

r=(x1!=x2)
print("!=",r)
# Out:
# entered number 1: 6
# entered number 2: 5
# == False
# > True
# < False
# >= True
# <= False
# != True
