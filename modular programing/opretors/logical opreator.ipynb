# %%
x1=6
x2=5
#   T          T
r=(x1>x2 and x2<x1)
print(r)


#   F          T
r=(x1<x2 and x2<x1)
print(r)

#   T          F
r=(x1>x2 and x2>x1)
print(r)

#   F          F
r=(x1<x2 and x2>x1)
print(r)
# Out:
# True
# False
# False
# False

# %%
x1=6
x2=5
#   T          T
r=(x1>x2 or x2<x1)
print(r)


#   F          T
r=(x1<x2 or x2<x1)
print(r)

#   T          F
r=(x1>x2 or x2>x1)
print(r)

#   F          F
r=(x1<x2 or x2>x1)
print(r)
# Out:
# True
# True
# True
# False

# %%
x1=6
x2=5
#         T          T
r=(not (x1>x2 and x2<x1))
print(r)


#        F          T
r=(not(x1<x2 and x2<x1))
print(r)

#        T          F
r=(not(x1>x2 and x2>x1))
print(r)

#        F          F
r=(not(x1<x2 and x2>x1))
print(r)
# Out:
# False
# True
# True
# True

# %%
### valurs opreator 




name="abbas"

if (n:=len(name))> 4:
    print("good name")
    
    
else :
    print("not good name ")
# Out:
# good name
